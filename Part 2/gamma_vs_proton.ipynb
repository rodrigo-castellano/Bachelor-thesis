# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot

import tensorflow as tf
from tensorflow import keras

# %%
# load numpy array from npy file
from numpy import load

dset2 = load('file/proton_image.npy')
dset = load('file/gamma_image_moved.npy')

# %%
#plot a image
import matplotlib.pyplot as plt
plt.imshow(dset[1], interpolation='none',aspect='auto')
fig_size = plt.rcParams["figure.figsize"]
plt.show()

# %% [markdown]
# # split data

# %%
#put the target together
target0=np.zeros(dset.shape[0])
target1=np.ones(dset2.shape[0])
target=np.concatenate((target0, target1), axis=0)
#put the dataset together
data=np.concatenate((dset, dset2), axis=0)

# %%
import sklearn
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.20, random_state=3)

# %%
# input image dimensions
imgRows, imgCols = 55, 93
numChannels=1
samples=X_train.shape[0]
numClasses=2

x_train=X_train
x_test=X_test

# #to put  the channels at the beginning
# x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
# x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
# input_shape = (1, img_rows, img_cols)

#to put  the channels at the end
x_train = x_train.reshape(x_train.shape[0], imgRows, imgCols, numChannels)
x_test = x_test.reshape(x_test.shape[0], imgRows, imgCols, numChannels)
input_shape = (imgRows, imgCols, numChannels)

# convert class vectors to binary class matrices
y_train_c = keras.utils.to_categorical(y_train, numClasses)
y_test_c = keras.utils.to_categorical(y_test, numClasses)

# %% [markdown]
# # Model 1: FC NN

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(numClasses, activation=tf.nn.softmax))
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# %%time
hist=model.fit(x_train, y_train, epochs=30, validation_data=(x_test, y_test)) #epochs es el numero de iteraciones hasta alcanzar un loss minimo
# Out:
# Epoch 1/30
# 393/393 [==============================] - 1s 4ms/step - loss: 0.1240 - accuracy: 0.9473 - val_loss: 0.0262 - val_accuracy: 0.9924
# Epoch 2/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0307 - accuracy: 0.9907 - val_loss: 0.0238 - val_accuracy: 0.9930
# Epoch 3/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0252 - accuracy: 0.9922 - val_loss: 0.0237 - val_accuracy: 0.9930
# Epoch 4/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0212 - accuracy: 0.9940 - val_loss: 0.0222 - val_accuracy: 0.9939
# Epoch 5/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0194 - accuracy: 0.9946 - val_loss: 0.0246 - val_accuracy: 0.9946
# Epoch 6/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0166 - accuracy: 0.9945 - val_loss: 0.0228 - val_accuracy: 0.9949
# Epoch 7/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0138 - accuracy: 0.9956 - val_loss: 0.0235 - val_accuracy: 0.9946
# Epoch 8/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0140 - accuracy: 0.9963 - val_loss: 0.0238 - val_accuracy: 0.9949
# Epoch 9/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0116 - accuracy: 0.9970 - val_loss: 0.0236 - val_accuracy: 0.9943
# Epoch 10/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0103 - accuracy: 0.9969 - val_loss: 0.0239 - val_accuracy: 0.9946
# Epoch 11/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0082 - accuracy: 0.9979 - val_loss: 0.0236 - val_accuracy: 0.9946
# Epoch 12/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0091 - accuracy: 0.9975 - val_loss: 0.0267 - val_accuracy: 0.9943
# Epoch 13/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0064 - accuracy: 0.9979 - val_loss: 0.0286 - val_accuracy: 0.9936
# Epoch 14/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0269 - val_accuracy: 0.9946
# Epoch 15/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0275 - val_accuracy: 0.9943
# Epoch 16/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0282 - val_accuracy: 0.9952
# Epoch 17/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0045 - accuracy: 0.9984 - val_loss: 0.0300 - val_accuracy: 0.9933
# Epoch 18/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.0308 - val_accuracy: 0.9930
# Epoch 19/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0299 - val_accuracy: 0.9946
# Epoch 20/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.0303 - val_accuracy: 0.9933
# Epoch 21/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0040 - accuracy: 0.9990 - val_loss: 0.0352 - val_accuracy: 0.9943
# Epoch 22/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.0334 - val_accuracy: 0.9946
# Epoch 23/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0458 - val_accuracy: 0.9904
# Epoch 24/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.0334 - val_accuracy: 0.9949
# Epoch 25/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.0345 - val_accuracy: 0.9939
# Epoch 26/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0466 - val_accuracy: 0.9917
# Epoch 27/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.0388 - val_accuracy: 0.9949
# Epoch 28/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0407 - val_accuracy: 0.9939
# Epoch 29/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.0399 - val_accuracy: 0.9943
# Epoch 30/30
# 393/393 [==============================] - 1s 3ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0436 - val_accuracy: 0.9939
# CPU times: user 43.9 s, sys: 4.88 s, total: 48.8 s
# Wall time: 39.6 s

# %%
val_loss, val_acc = model.evaluate(X_test, y_test)
# print(val_loss)
print(val_acc)

from sklearn.metrics import classification_report, confusion_matrix
y_pred = model.predict_classes(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 99/99 [==============================] - 0s 2ms/step - loss: 0.0436 - accuracy: 0.9939
# 0.9939490556716919
# WARNING:tensorflow:From <ipython-input-15-ff74f486f7d2>:6: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# [[2405    4]
#  [  15  716]]
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      2409
#          1.0       0.99      0.98      0.99       731
#
#     accuracy                           0.99      3140
#    macro avg       0.99      0.99      0.99      3140
# weighted avg       0.99      0.99      0.99      3140

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# # model 2: CNN

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D

def create_model(padding='same',stride=2,pool=2,filters=64,kernel=5,hidden_layers=2,neurons=20,optimizer='Adadelta',
                 learn_rate=0.001, init_mode='glorot_normal', activation='relu', dropout_rate=0.4,
                 weight_constraint=None,weight_regularizer=None, batchn=0,conv=2, n_filters=2):#parameters here are default

    # initialize the model
    model = Sequential()                                                                       

    for i in range (conv):
        num=int(round(filters*(2**(i-1))))
        for i in range (n_filters):
              model.add(Conv2D(num, kernel, padding=padding,activation=activation,kernel_initializer=init_mode,kernel_constraint=weight_constraint,kernel_regularizer=weight_regularizer))
        model.add(MaxPooling2D(pool_size=(pool, pool), strides=(stride, stride)))
        # model.add(Dropout(dropout_rate))
    # define the first FC => ACTIVATION layers
    model.add(Flatten())
    if (batchn==1):
        model.add(BatchNormalization())     
    model.add(Dropout(dropout_rate)) 
    for i in range(hidden_layers):
        model.add(Dense(neurons,kernel_initializer=init_mode,  activation=activation,kernel_regularizer=weight_regularizer)) 
        if (batchn==1):
            model.add(BatchNormalization())    #, use_bias=False
        model.add(Dropout(dropout_rate)) 
    # lastly, define the soft-max classifier
    model.add(Dense(numClasses, activation='softmax'))

    if (optimizer=='SGD'):
        optimizer = keras.optimizers.SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
    elif (optimizer=='RMS'):
        optimizer=keras.optimizers.RMSprop(learning_rate=0.001, rho=0.9)
    elif (optimizer=='Adagrad'):
        optimizer=keras.optimizers.Adagrad(learning_rate=0.01)
    elif (optimizer=='Adadelta'):
        optimizer=keras.optimizers.Adadelta(learning_rate=1.0, rho=0.95)
    elif (optimizer=='Adamax'):
        optimizer=keras.optimizers.Adamax(learning_rate=0.002, beta_1=0.9, beta_2=0.999)
    elif (optimizer=='Nadam'):
        optimizer=keras.optimizers.Nadam(learning_rate=0.002, beta_1=0.9, beta_2=0.999)
    elif (optimizer=='Adam'):
        optimizer=keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)

    model.compile(optimizer=optimizer,loss='sparse_categorical_crossentropy',metrics=['accuracy'])              

    return model
# Out:
# Using TensorFlow backend.

# %%
shape=x_train.shape
model=create_model()
model.build(shape) 
model.summary()
model=create_model()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (12556, 55, 93, 32)       832
# _________________________________________________________________
# conv2d_2 (Conv2D)            (12556, 55, 93, 32)       25632
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (12556, 27, 46, 32)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (12556, 27, 46, 64)       51264
# _________________________________________________________________
# conv2d_4 (Conv2D)            (12556, 27, 46, 64)       102464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (12556, 13, 23, 64)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (12556, 19136)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (12556, 19136)            0
# _________________________________________________________________
# dense_1 (Dense)              (12556, 20)               382740
# _________________________________________________________________
# dropout_2 (Dropout)          (12556, 20)               0
# _________________________________________________________________
# dense_2 (Dense)              (12556, 20)               420
# _________________________________________________________________
# dropout_3 (Dropout)          (12556, 20)               0
# _________________________________________________________________
# dense_3 (Dense)              (12556, 2)                42
# =================================================================
# Total params: 563,394
# Trainable params: 563,394
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
history=model.fit(x_train, y_train, epochs=30,batch_size=128, validation_data=(x_test, y_test))
# Out:
# Train on 12556 samples, validate on 3140 samples
# Epoch 1/30
# 12556/12556 [==============================] - 7s 521us/step - loss: 0.0770 - accuracy: 0.9806 - val_loss: 0.0441 - val_accuracy: 0.9879
# Epoch 2/30
# 12556/12556 [==============================] - 6s 517us/step - loss: 0.0680 - accuracy: 0.9840 - val_loss: 0.0338 - val_accuracy: 0.9914
# Epoch 3/30
# 12556/12556 [==============================] - 7s 524us/step - loss: 0.0594 - accuracy: 0.9869 - val_loss: 0.0387 - val_accuracy: 0.9876
# Epoch 4/30
# 12556/12556 [==============================] - 7s 526us/step - loss: 0.0474 - accuracy: 0.9885 - val_loss: 0.0275 - val_accuracy: 0.9927
# Epoch 5/30
# 12556/12556 [==============================] - 7s 533us/step - loss: 0.0461 - accuracy: 0.9889 - val_loss: 0.0330 - val_accuracy: 0.9930
# Epoch 6/30
# 12556/12556 [==============================] - 7s 532us/step - loss: 0.0443 - accuracy: 0.9885 - val_loss: 0.0300 - val_accuracy: 0.9933
# Epoch 7/30
# 12556/12556 [==============================] - 7s 531us/step - loss: 0.0449 - accuracy: 0.9890 - val_loss: 0.0346 - val_accuracy: 0.9904
# Epoch 8/30
# 12556/12556 [==============================] - 7s 532us/step - loss: 0.0371 - accuracy: 0.9917 - val_loss: 0.0276 - val_accuracy: 0.9933
# Epoch 9/30
# 12556/12556 [==============================] - 7s 527us/step - loss: 0.0390 - accuracy: 0.9901 - val_loss: 0.0244 - val_accuracy: 0.9946
# Epoch 10/30
# 12556/12556 [==============================] - 7s 527us/step - loss: 0.0360 - accuracy: 0.9907 - val_loss: 0.0224 - val_accuracy: 0.9943
# Epoch 11/30
# 12556/12556 [==============================] - 7s 527us/step - loss: 0.0320 - accuracy: 0.9916 - val_loss: 0.0572 - val_accuracy: 0.9790
# Epoch 12/30
# 12556/12556 [==============================] - 7s 527us/step - loss: 0.0377 - accuracy: 0.9904 - val_loss: 0.0228 - val_accuracy: 0.9949
# Epoch 13/30
# 12556/12556 [==============================] - 7s 527us/step - loss: 0.0314 - accuracy: 0.9917 - val_loss: 0.0248 - val_accuracy: 0.9933
# Epoch 14/30
# 12556/12556 [==============================] - 7s 526us/step - loss: 0.0312 - accuracy: 0.9924 - val_loss: 0.0242 - val_accuracy: 0.9933
# Epoch 15/30
# 12556/12556 [==============================] - 7s 527us/step - loss: 0.0269 - accuracy: 0.9920 - val_loss: 0.0224 - val_accuracy: 0.9939
# Epoch 16/30
# 12556/12556 [==============================] - 7s 530us/step - loss: 0.0286 - accuracy: 0.9917 - val_loss: 0.0223 - val_accuracy: 0.9949
# Epoch 17/30
# 12556/12556 [==============================] - 7s 530us/step - loss: 0.0263 - accuracy: 0.9925 - val_loss: 0.0200 - val_accuracy: 0.9952
# Epoch 18/30
# 12556/12556 [==============================] - 7s 532us/step - loss: 0.0245 - accuracy: 0.9930 - val_loss: 0.0241 - val_accuracy: 0.9949
# Epoch 19/30
# 12556/12556 [==============================] - 7s 532us/step - loss: 0.0249 - accuracy: 0.9931 - val_loss: 0.0211 - val_accuracy: 0.9946
# Epoch 20/30
# 12556/12556 [==============================] - 7s 531us/step - loss: 0.0235 - accuracy: 0.9932 - val_loss: 0.0237 - val_accuracy: 0.9943
# Epoch 21/30
# 12556/12556 [==============================] - 7s 531us/step - loss: 0.0294 - accuracy: 0.9926 - val_loss: 0.0195 - val_accuracy: 0.9946
# Epoch 22/30
# 12556/12556 [==============================] - 7s 531us/step - loss: 0.0273 - accuracy: 0.9936 - val_loss: 0.0209 - val_accuracy: 0.9939
# Epoch 23/30
# 12556/12556 [==============================] - 7s 529us/step - loss: 0.0229 - accuracy: 0.9942 - val_loss: 0.0225 - val_accuracy: 0.9943
# Epoch 24/30
# 12556/12556 [==============================] - 7s 529us/step - loss: 0.0232 - accuracy: 0.9939 - val_loss: 0.0225 - val_accuracy: 0.9946
# Epoch 25/30
# 12556/12556 [==============================] - 7s 529us/step - loss: 0.0228 - accuracy: 0.9936 - val_loss: 0.0230 - val_accuracy: 0.9946
# Epoch 26/30
# 12556/12556 [==============================] - 7s 533us/step - loss: 0.0217 - accuracy: 0.9938 - val_loss: 0.0309 - val_accuracy: 0.9898
# Epoch 27/30
# 12556/12556 [==============================] - 7s 533us/step - loss: 0.0236 - accuracy: 0.9946 - val_loss: 0.0226 - val_accuracy: 0.9927
# Epoch 28/30
# 12556/12556 [==============================] - 7s 530us/step - loss: 0.0228 - accuracy: 0.9948 - val_loss: 0.0221 - val_accuracy: 0.9943
# Epoch 29/30
# 12556/12556 [==============================] - 7s 529us/step - loss: 0.0220 - accuracy: 0.9941 - val_loss: 0.0244 - val_accuracy: 0.9930
# Epoch 30/30
# 12556/12556 [==============================] - 7s 529us/step - loss: 0.0211 - accuracy: 0.9943 - val_loss: 0.0208 - val_accuracy: 0.9949
# CPU times: user 1min 44s, sys: 46.5 s, total: 2min 30s
# Wall time: 3min 19s

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %%
val_loss, val_acc = model.evaluate(x_test, y_test)
# print(val_loss)
print(val_acc)

from sklearn.metrics import classification_report, confusion_matrix
y_pred = model.predict_classes(x_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 3140/3140 [==============================] - 1s 302us/step
# 0.9949044585227966
# [[2399   10]
#  [   6  725]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      2409
#          1.0       0.99      0.99      0.99       731
#
#     accuracy                           0.99      3140
#    macro avg       0.99      0.99      0.99      3140
# weighted avg       0.99      0.99      0.99      3140

# %%
#SAVE RESULTS
# history = pd.DataFrame(history.history)
# history.to_csv('history/history_2.csv', index=False)
# #LOAD RESULTS
# import pandas as pd
# import csv
# history = pd.read_csv('history/history.csv', delimiter=',')

# SAVE THE MODEL
# model.save('model/all_all_2.model')
# #Load it back:
model = tf.keras.models.load_model('model/all_all_2.model')

# %% [markdown]
# # Results

# %%
class_names = ['gamma', 'proton']

# %%
#show images in general

y_train=y_train.astype(int)
y_test=y_test.astype(int)
plt.figure(figsize=(20,20))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %%
predictions = model.predict(x_test)
print(predictions[0])
np.argmax(predictions[0])
y_pred = model.predict_classes(x_test)
# Out:
# [4.573345e-05 9.999542e-01]

# %%
#define a function to create images that show classification


def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)#, cmap=plt.cm.binary

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(7), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
#For instance, here I can select wrong classification  for a certain praticle

index=np.where((y_test==0) & (y_pred!=y_test))[0]
index2=np.where((y_test==1)& (y_pred!=y_test))[0]
# index=np.concatenate([index1,index2])
index=np.sort(index)
incorrect = np.where(y_pred!=y_test)[0]
correct = np.where(y_pred==y_test)[0]
len(incorrect)
# Out:
# 16

# %%
num_rows = 100
num_cols = 2
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols+10, 2*num_rows+10))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[incorrect][i], y_test[incorrect], X_test[incorrect])
#   plt.subplot(num_rows, 2*num_cols, 2*i+2)
#   plot_value_array(i, predictions[i],  y_test)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-9c53de8a3847> in <module>()
#       5 for i in range(num_images):
#       6   plt.subplot(num_rows, 2*num_cols, 2*i+1)
# ----> 7   plot_image(i, predictions[incorrect][i], y_test[incorrect], X_test[incorrect])
#       8 #   plt.subplot(num_rows, 2*num_cols, 2*i+2)
#       9 #   plot_value_array(i, predictions[i],  y_test)
#
# IndexError: index 16 is out of bounds for axis 0 with size 16
