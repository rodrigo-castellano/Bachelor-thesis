# %% [markdown]
# <b>COSMIC RADIATION: Support vectors machine</b>
#
# rodrigoX: Contains 4 parameters
#     1. NALLParticlesTotal : Total number of particles generated by the event in the ground level.
#     2. MUTotal : Total number of muons.
#     3. ELTotal : Total number of electromagnetic particles.
#     4. Zenith : Zenith angle of the particle [degrees].
#     5. Energy : Particle energy [GeV].
#
# rodrigoY: contains the target
#     Labels: photon, proton, helium, nitrogen, iron.
#         the smallest number is assigned to photon (A=0) and the highest number to the heaviest particle, this is, iron (B=4).
#
#         0==photon     1==proton    2==helium     3==nitrogen   4==iron

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.svm import SVC  
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### data

# %%
#leave the dataset ready
df_x = pd.read_fwf('XRodrigo.txt')
df_x.columns = ["NALLParticlesTotal", "MUTotal", "ELTotal", "Zenith","Energy"]
df_y=pd.read_fwf('YRodrigo.txt')
df_y.columns = ["Particle"]

transpose=df_x.T
transpose_y=df_y.T #Transpose to put them together
df_tot = transpose.append(transpose_y)
df_tot=df_tot.T.sample(frac=1).reset_index(drop=True)#este el el df completo y barajado

df_y=df_tot[['Particle']]
df_x=df_tot[["NALLParticlesTotal", "MUTotal", "ELTotal", "Zenith","Energy"]]

# %%
#train-test split and reescale
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
X_train, X_test, y_train, y_test = train_test_split(df_x, df_y, random_state=0,test_size = 0.25)
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
y_test_np=y_test.to_numpy()
y_train_np=y_train.to_numpy().flatten()

# %% [markdown]
# ### Grid search

# %%
# %%time
param_grid = {'C': [0.5,1, 10,50, 100], 'gamma': [1,4,7,10],'kernel': ['rbf']}
grid = GridSearchCV(SVC(), param_grid , n_jobs=-1, cv=5, verbose=1)
grid_result= grid.fit(X_train,y_train)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] C=0.5, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=0.5, gamma=1, kernel=rbf, total=  23.1s
# [CV] C=0.5, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   23.0s remaining:    0.0s
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=0.5, gamma=1, kernel=rbf, total=  24.5s
# [CV] C=0.5, gamma=1, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=0.5, gamma=1, kernel=rbf, total=  25.1s
# [CV] C=0.5, gamma=4, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=0.5, gamma=4, kernel=rbf, total=  20.1s
# [CV] C=0.5, gamma=4, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=0.5, gamma=4, kernel=rbf, total=  19.4s
# [CV] C=0.5, gamma=4, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=0.5, gamma=4, kernel=rbf, total=  19.3s
# [CV] C=0.5, gamma=7, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=0.5, gamma=7, kernel=rbf, total=  17.4s
# [CV] C=0.5, gamma=7, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=0.5, gamma=7, kernel=rbf, total=  19.4s
# [CV] C=0.5, gamma=7, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=0.5, gamma=7, kernel=rbf, total=  17.7s
# [CV] C=0.5, gamma=10, kernel=rbf .....................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ...................... C=0.5, gamma=10, kernel=rbf, total=  16.3s
# [CV] C=0.5, gamma=10, kernel=rbf .....................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ...................... C=0.5, gamma=10, kernel=rbf, total=  16.8s
# [CV] C=0.5, gamma=10, kernel=rbf .....................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ...................... C=0.5, gamma=10, kernel=rbf, total=  17.0s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ......................... C=1, gamma=1, kernel=rbf, total=  19.1s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ......................... C=1, gamma=1, kernel=rbf, total=  19.2s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ......................... C=1, gamma=1, kernel=rbf, total=  19.3s
# [CV] C=1, gamma=4, kernel=rbf ........................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ......................... C=1, gamma=4, kernel=rbf, total=  16.2s
# [CV] C=1, gamma=4, kernel=rbf ........................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ......................... C=1, gamma=4, kernel=rbf, total=  16.1s
# [CV] C=1, gamma=4, kernel=rbf ........................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ......................... C=1, gamma=4, kernel=rbf, total=  16.6s
# [CV] C=1, gamma=7, kernel=rbf ........................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ......................... C=1, gamma=7, kernel=rbf, total=  16.4s
# [CV] C=1, gamma=7, kernel=rbf ........................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ......................... C=1, gamma=7, kernel=rbf, total=  15.5s
# [CV] C=1, gamma=7, kernel=rbf ........................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ......................... C=1, gamma=7, kernel=rbf, total=  15.2s
# [CV] C=1, gamma=10, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=1, gamma=10, kernel=rbf, total=  15.1s
# [CV] C=1, gamma=10, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=1, gamma=10, kernel=rbf, total=  17.9s
# [CV] C=1, gamma=10, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=1, gamma=10, kernel=rbf, total=  17.9s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=  14.2s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=  14.0s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=  14.4s
# [CV] C=10, gamma=4, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=10, gamma=4, kernel=rbf, total=  13.0s
# [CV] C=10, gamma=4, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=10, gamma=4, kernel=rbf, total=  12.0s
# [CV] C=10, gamma=4, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=10, gamma=4, kernel=rbf, total=  11.5s
# [CV] C=10, gamma=7, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=10, gamma=7, kernel=rbf, total=  11.9s
# [CV] C=10, gamma=7, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=10, gamma=7, kernel=rbf, total=  11.0s
# [CV] C=10, gamma=7, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=10, gamma=7, kernel=rbf, total=  11.0s
# [CV] C=10, gamma=10, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=10, gamma=10, kernel=rbf, total=  11.3s
# [CV] C=10, gamma=10, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=10, gamma=10, kernel=rbf, total=  11.5s
# [CV] C=10, gamma=10, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=10, gamma=10, kernel=rbf, total=  11.7s
# [CV] C=50, gamma=1, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=50, gamma=1, kernel=rbf, total=  13.4s
# [CV] C=50, gamma=1, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=50, gamma=1, kernel=rbf, total=  14.0s
# [CV] C=50, gamma=1, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=50, gamma=1, kernel=rbf, total=  11.7s
# [CV] C=50, gamma=4, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=50, gamma=4, kernel=rbf, total=  11.0s
# [CV] C=50, gamma=4, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=50, gamma=4, kernel=rbf, total=   9.4s
# [CV] C=50, gamma=4, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=50, gamma=4, kernel=rbf, total=  10.4s
# [CV] C=50, gamma=7, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=50, gamma=7, kernel=rbf, total=   9.1s
# [CV] C=50, gamma=7, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=50, gamma=7, kernel=rbf, total=   9.1s
# [CV] C=50, gamma=7, kernel=rbf .......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ........................ C=50, gamma=7, kernel=rbf, total=   9.3s
# [CV] C=50, gamma=10, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=50, gamma=10, kernel=rbf, total=   9.4s
# [CV] C=50, gamma=10, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=50, gamma=10, kernel=rbf, total=   8.9s
# [CV] C=50, gamma=10, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=50, gamma=10, kernel=rbf, total=   8.6s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=  10.8s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=  11.1s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=  11.8s
# [CV] C=100, gamma=4, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=100, gamma=4, kernel=rbf, total=  10.0s
# [CV] C=100, gamma=4, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=100, gamma=4, kernel=rbf, total=  10.2s
# [CV] C=100, gamma=4, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=100, gamma=4, kernel=rbf, total=   9.3s
# [CV] C=100, gamma=7, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=100, gamma=7, kernel=rbf, total=   8.7s
# [CV] C=100, gamma=7, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=100, gamma=7, kernel=rbf, total=   8.3s
# [CV] C=100, gamma=7, kernel=rbf ......................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ....................... C=100, gamma=7, kernel=rbf, total=   9.0s
# [CV] C=100, gamma=10, kernel=rbf .....................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ...................... C=100, gamma=10, kernel=rbf, total=   8.4s
# [CV] C=100, gamma=10, kernel=rbf .....................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ...................... C=100, gamma=10, kernel=rbf, total=   8.3s
# [CV] C=100, gamma=10, kernel=rbf .....................................
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV] ...................... C=100, gamma=10, kernel=rbf, total=   7.9s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed: 13.8min finished
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Wall time: 14min
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='auto_deprecated', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'C': [0.5, 1, 10, 50, 100], 'gamma': [1, 4, 7, 10],
#                          'kernel': ['rbf']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
print(grid_result)
print("The best parameters are %s with a score of %0.5f"
      % (grid_result.best_params_, grid_result.best_score_))
results = pd.DataFrame(grid.cv_results_)
results.to_csv('grid-search-results-01.csv', index=False)
# Out:
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='auto_deprecated', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'C': [0.5, 1, 10, 50, 100], 'gamma': [1, 4, 7, 10],
#                          'kernel': ['rbf']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)
# 0.8945582281495594
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=10, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# ### Model

# %%
#gaussian kernel. More choices: linear, poly, sigmoid
svclassifier = SVC(kernel='rbf')
svclassifier.fit(X_train, y_train)

# %%
y_pred = svclassifier.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print(accuracy_score(y_test, datatest))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# [[2124    0    0    0    0]
#  [ 535  579  304  668    0]
#  [ 533    9  538 1003   35]
#  [ 448    8  148 1312   98]
#  [ 424    0   99 1267  366]]
#               precision    recall  f1-score   support
#
#          0.0       0.52      1.00      0.69      2124
#          1.0       0.97      0.28      0.43      2086
#          2.0       0.49      0.25      0.34      2118
#          3.0       0.31      0.65      0.42      2014
#          4.0       0.73      0.17      0.28      2156
#
#     accuracy                           0.47     10498
#    macro avg       0.61      0.47      0.43     10498
# weighted avg       0.61      0.47      0.43     10498
